# %%
pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 957.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.1 MB/s eta 0:00:00
# ...

# %%
# !pip install torch transformers peft accelerate datasets pdfplumber

# %%
# !unzip /content/Selected20PDF.zip -d /content
# Out:
# Archive:  /content/Selected20PDF.zip
#   inflating: /content/Selected_20_PDFs/NKTXPVJPY5TFHGLN3JTGGFE7R6KEJJI4.pdf
#   inflating: /content/Selected_20_PDFs/NXQWVJBI6J23JG35UF2PBILHUJXOKLKW.pdf
#   inflating: /content/Selected_20_PDFs/4L35CSXFUATM7UTMSDUPULOT54HTIGRP.pdf
#   inflating: /content/Selected_20_PDFs/ODFH5YT72ZKNG6YGIOKCH67FDHEFFFM3.pdf
#   inflating: /content/Selected_20_PDFs/PFGSA5KKI3RCAENXBCM2LGTLHH5TLRGG.pdf
#   inflating: /content/Selected_20_PDFs/D6HDJJ7UEFJGI3ZLUWIWMZHJJDO7MRGC.pdf
#   inflating: /content/Selected_20_PDFs/RDQEO3IHCUXHQO3INBQKLFGDQOCQJ2QS.pdf
#   inflating: /content/Selected_20_PDFs/OGOIOJCYO3VA7JT3K5N3OVKM4PB2BF7K.pdf
#   inflating: /content/Selected_20_PDFs/KEAHFYXS23DKDX43I4DYM6LBJD6H6FMP.pdf
#   inflating: /content/Selected_20_PDFs/NLALJLUHGUMMXT4J7U6N334L5AEG7PMR.pdf
#   inflating: /content/Selected_20_PDFs/BUDP7F2VA32OORAA4TZ5OYZRYYLZGMDK.pdf
#   inflating: /content/Selected_20_PDFs/IKOIMACPLTOKKI2XAQPQOCR7HL2E7MCY.pdf
# ...

# %%
# !python extract_text.py
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# ...

# %%
! python prepare_dataset.py
# Out:
# tokenizer_config.json: 100% 746/746 [00:00<00:00, 3.98MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 12.1MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 24.3MB/s]
# added_tokens.json: 100% 21.0/21.0 [00:00<00:00, 127kB/s]
# special_tokens_map.json: 100% 435/435 [00:00<00:00, 2.15MB/s]
# Map: 100% 1375/1375 [00:00<00:00, 1852.66 examples/s]
# Saving the dataset (1/1 shards): 100% 1375/1375 [00:00<00:00, 88639.75 examples/s]
# ✅ Tokenized dataset saved to /content/tokenized_dataset

# %%
pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 MB 12.4 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall torch torchvision torchaudio -y
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers==4.39.3 datasets peft accelerate bitsandbytes trl

# %%
import torch
import transformers
import peft
import bitsandbytes as bnb

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device:", torch.cuda.get_device_name(0))
print("Transformers version:", transformers.__version__)
print("PEFT version:", peft.__version__)

# %%
from huggingface_hub import login
login()  # Enter your HF token when prompted

# %%
! python fine_tune.py
# Out:
# 2025-03-30 17:45:12.411268: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743356712.675750    4275 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743356712.750882    4275 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-30 17:45:13.286113: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !pip uninstall -y torch
# !pip uninstall -y torch torchaudio torchvision  # Remove all PyTorch components
# !pip cache purge  # Clear any cached versions

# ✅ Reinstall PyTorch (Stable Version for CUDA 11.8 in Colab)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import PeftModel
import torch

base_model_name = "tiiuae/falcon-7b-instruct"
adapter_path = "/content/drive/MyDrive/dummy_extracted_pdfs/fine_tuned_model"

# ✅ Enable 4-bit Quantization (to avoid memory crash)
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
) if torch.cuda.is_available() else None

# ✅ Load base model with quantization
model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    quantization_config=bnb_config,
    device_map="auto"  # Automatically place on GPU if available
)

# ✅ Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model_name)

# ✅ Apply LoRA adapter
model = PeftModel.from_pretrained(model, adapter_path)

# ✅ Move to GPU if available
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

# ✅ Test it
text = "Answer strictly based on the case file: What was the court's decision regarding Obergefell in this case?"
inputs = tokenizer(text, return_tensors="pt").to(device)
outputs = model.generate(**inputs)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
